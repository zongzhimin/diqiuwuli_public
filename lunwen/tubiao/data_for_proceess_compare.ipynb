# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from experiment1.model_em1 import FCZipSeismicDataV4
import numpy as np
import matplotlib.pyplot as plt

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
import json

# %%
data_json_f = open(r'E:\tools\写论文\图表数据\预处理与未预处理对比\run-loss_all_dropout_2-tag-dev_loss.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train = np.array(data_json)
loss_un_index = loss_train[:,1]
loss_un_loss = loss_train[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\预处理与未预处理对比\run-loss_all_dropout-tag-dev_loss.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train = np.array(data_json)
loss_pro_index = loss_train[:,1]
loss_pro_loss = loss_train[:,2]

# %%
len(loss_pro_index)
# Out:
# 1000

# %%
len(loss_pro_loss[start2:end2])
# Out:
# 1000

# %%
start1=10
start2=10
end1 = 1000
end2 = 1000

plt.figure(figsize=(10,4))
plt.suptitle('预处理与未预处理对训练的影响',y=1.05,fontsize='xx-large')
plt.subplot(1, 2, 1)

plt.title("未预处理的训练集loss")
plt.ylabel("loss")
plt.xlabel("迭代次数")
plt.plot(loss_un_index[start1:end1],loss_un_loss[start1:end1],label='未预处理数据训练时loss变化')
plt.legend()

plt.subplot(1, 2, 2)
plt.title("预处理后的训练集loss")
plt.ylabel("loss")
plt.xlabel("迭代次数")
plt.plot(loss_pro_index[start2:end2],loss_pro_loss[start2:end2],label='预处理后数据训练时loss变化')
plt.legend()

plt.savefig(r'E:\tools\写论文\图表数据\预处理与未预处理对比\预处理与未预处理对比.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)
