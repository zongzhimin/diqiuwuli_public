# %%
import numpy as np
# from tensorflow.keras import optimizers,Sequential, layers, Model
import matplotlib.pyplot as plt
# import tensorflow as tf


from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

import json

# %%
from matplotlib import colors

# %%
data_json_f = open(r'E:\tools\写论文\图表数据\三层向斜背斜预测\深度\loss\run-loss_all_layer3_fc_depth_4-tag-train_loss_depth.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train_depth = np.array(data_json)
loss_train_depth_index = loss_train_depth[:,1]
loss_train_depth_loss = loss_train_depth[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\三层向斜背斜预测\深度\loss\run-loss_all_layer3_fc_depth_4-tag-dev_loss_depth.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_dev_depth = np.array(data_json)
loss_dev_depth_index = loss_dev_depth[:,1]
loss_dev_depth_loss = loss_dev_depth[:,2]

# %%
loss_dev_depth_loss.shape
# Out:
# (90,)

# %%
loss_train_depth_loss.shape
# Out:
# (1000,)

# %%
start = 26
start2 = 3
plt.title("三层深度预测，训练中loss变化")
plt.ylabel("loss")
plt.xlabel("迭代次数")
plt.plot(loss_train_depth_index[start:],loss_train_depth_loss[start:],label='train_loss')
plt.plot(loss_dev_depth_index[start2:],loss_dev_depth_loss[start2:],label='dev_loss')
plt.legend()
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\深度\三层深度预测训练中loss变化.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)

# %%
data_json_f = open(r'E:\tools\写论文\图表数据\三层向斜背斜预测\速度\loss\run-loss_all_layer3_fc_speed_2-tag-dev_loss_speed.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_dev_speed = np.array(data_json)
loss_dev_speed_index = loss_dev_speed[:,1]
loss_dev_speed_loss = loss_dev_speed[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\三层向斜背斜预测\速度\loss\run-loss_all_layer3_fc_speed_2-tag-train_loss_speed.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train_speed = np.array(data_json)
loss_train_speed_index = loss_train_speed[:,1]
loss_train_speed_loss = loss_train_speed[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\三层向斜背斜预测\速度\acc\run-loss_all_layer3_fc_speed_2-tag-dev_acc.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_dev_acc = np.array(data_json)
loss_dev_acc_index = loss_dev_acc[:,1]
loss_dev_acc_loss = loss_dev_acc[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\三层向斜背斜预测\速度\acc\run-loss_all_layer3_fc_speed_2-tag-train_acc.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train_acc = np.array(data_json)
loss_train_acc_index = loss_train_acc[:,1]
loss_train_acc_loss = loss_train_acc[:,2]

# %%
start = 0
start2 = 0
plt.title("三层速度预测，训练准确率变化")
plt.ylabel("准确率")
plt.xlabel("迭代次数")
plt.plot(loss_dev_acc_index[start:],loss_dev_acc_loss[start:],label='dev_acc')
plt.plot(loss_train_acc_index[start2:],loss_train_acc_loss[start2:],label='train_acc')
plt.legend()
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\速度\三层速度预测训练中准确率变化.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)

# %%
loss_dev_acc_loss[-1],loss_train_acc_loss[-1]
# Out:
# (0.75628662109375, 0.9556477665901184)

# %%
start = 0
start2 = 0
plt.title("三层速度预测，训练中loss变化")
plt.ylabel("loss")
plt.xlabel("迭代次数")
plt.plot(loss_dev_speed_index[start:],loss_dev_speed_loss[start:],label='dev_loss')
plt.plot(loss_train_speed_index[start2:],loss_train_speed_loss[start2:],label='train_loss')
plt.legend()
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\速度\三层速度预测训练中loss变化.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)

# %%
y_class = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_class_512_1_train.npy')
y_depth = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_depth_512_1_test.npy')

# %%
y_class.shape,y_depth.shape
# Out:
# ((512, 4), (512, 3, 256))

# %%
speed_list = [1500,1725,2000,2250,2500,2750,3000,3250]

# %%
y_class[0]
# Out:
# array([0., 1., 4., 6.], dtype=float32)

# %%
int(y_class[0,0])
# Out:
# 0

# %%
layer1 = np.zeros((256,256))
num = 0
for i in range(256):
    layer1[0:int(y_depth[num,0,i]),i] = speed_list[int(y_class[num,0])]
    layer1[int(y_depth[num,0,i]):int(y_depth[num,1,i]),i] = speed_list[int(y_class[num,1])]
    layer1[int(y_depth[num,1,i]):int(y_depth[num,2,i]),i] = speed_list[int(y_class[num,2])]
    layer1[int(y_depth[num,2,i]):,i] = speed_list[int(y_class[num,3])]

layer2 = np.zeros((256,256))
num = 1    
for i in range(256):
    layer2[0:int(y_depth[num,0,i]),i] = speed_list[int(y_class[num,0])]
    layer2[int(y_depth[num,0,i]):int(y_depth[num,1,i]),i] = speed_list[int(y_class[num,1])]
    layer2[int(y_depth[num,1,i]):int(y_depth[num,2,i]),i] = speed_list[int(y_class[num,2])]
    layer2[int(y_depth[num,2,i]):,i] = speed_list[int(y_class[num,3])]

layer3 = np.zeros((256,256))
num = 2
for i in range(256):
    layer3[0:int(y_depth[num,0,i]),i] = speed_list[int(y_class[num,0])]
    layer3[int(y_depth[num,0,i]):int(y_depth[num,1,i]),i] = speed_list[int(y_class[num,1])]
    layer3[int(y_depth[num,1,i]):int(y_depth[num,2,i]),i] = speed_list[int(y_class[num,2])]
    layer3[int(y_depth[num,2,i]):,i] = speed_list[int(y_class[num,3])]

layer4 = np.zeros((256,256))
num = 3
for i in range(256):
    layer4[0:int(y_depth[num,0,i]),i] = speed_list[int(y_class[num,0])]
    layer4[int(y_depth[num,0,i]):int(y_depth[num,1,i]),i] = speed_list[int(y_class[num,1])]
    layer4[int(y_depth[num,1,i]):int(y_depth[num,2,i]),i] = speed_list[int(y_class[num,2])]
    layer4[int(y_depth[num,2,i]):,i] = speed_list[int(y_class[num,3])]

# %%
plt.imshow(layer2)

# %%
vpdatas = [layer1,layer2,layer3,layer4]

# %%
Nr = 1
Nc = 4

fig, axs = plt.subplots(Nr, Nc,figsize=(12, 8))
fig.suptitle('三层向斜背斜地层模型',y=0.75,fontsize='xx-large')

images = []
# for i in range(Nr):
for j in range(Nc):
    # Generate data with a range that varies from one plot to the next.
    axs[j].xaxis.set_ticks_position('top')
    axs[j].set_xlabel('距离（m）')
    axs[j].set_ylabel('深度（m）')
    axs[j].set_xticks([0,100,200])
    axs[j].set_xticklabels([0,400,800])
    axs[j].set_yticks([0,50,100,150,200,250])
    axs[j].set_yticklabels([0,200,400,600,800,1000])
    axs[j].xaxis.set_label_position('top')
    images.append(axs[j].imshow(vpdatas[j]))
    axs[j].label_outer()

# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.28, 0.765, 0.04])#位置[左,y,右,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='x-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\三层向斜背斜地层模型.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()

# %%
y_class_512_1_test = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_class_512_1_test.npy')
y_test_speed_pred_1 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_speed_pred_1.npy')
y_depth_512_1_test = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_depth_512_1_test.npy')
y_test_depth_pred_1 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_depth_pred_1.npy')/4
y_depth_512_2_test = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_depth_512_2_test.npy')
y_test_depth_pred_2 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_depth_pred_2.npy')/4
y_depth_512_3_test = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_depth_512_3_test.npy')
y_test_depth_pred_3 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_depth_pred_3.npy')/4
y_depth_512_4_test = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_depth_512_4_test.npy')
y_test_depth_pred_4 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_depth_pred_4.npy')/4

# %%
y_test_speed_pred_1[16],y_class_512_1_test[16]
# Out:
# (array([3, 4, 5, 6], dtype=int64), array([3., 4., 5., 7.], dtype=float32))

# %%
np.mean(np.abs(y_depth_512_1_test*4-y_test_depth_pred_1))
+ np.mean(np.abs(y_depth_512_2_test*4-y_test_depth_pred_2))
+ np.mean(np.abs(y_depth_512_3_test*4-y_test_depth_pred_3))
+ np.mean(np.abs(y_depth_512_4_test*4-y_test_depth_pred_4))
# Out:
# 28.392698

# %%
np.mean(np.abs(y_depth_512_4_test-y_test_depth_pred_4/4))
# Out:
# 7.0981746

# %%
layer_true_1 = np.zeros((256,256))
num = 8
for i in range(256):
    layer_true_1[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_1[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_1[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_1[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_2 = np.zeros((256,256))
num = 16    
for i in range(256):
    layer_true_2[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_2[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_2[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_2[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_3 = np.zeros((256,256))
num = 32
for i in range(256):
    layer_true_3[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_3[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_3[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_3[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_4 = np.zeros((256,256))
num = 64
for i in range(256):
    layer_true_4[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_4[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_4[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_4[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

# %%
layers_true = [layer_true_1,layer_true_2,layer_true_3,layer_true_4]

# %%
Nr = 1
Nc = 4

fig, axs = plt.subplots(Nr, Nc,figsize=(12, 8))
fig.suptitle('三层向斜背斜地层真实模型',y=0.75,fontsize='xx-large')

images = []
# for i in range(Nr):
for j in range(Nc):
    # Generate data with a range that varies from one plot to the next.
    axs[j].xaxis.set_ticks_position('top')
    axs[j].set_xlabel('距离（m）')
    axs[j].set_ylabel('深度（m）')
    axs[j].set_xticks([0,100,200])
    axs[j].set_xticklabels([0,400,800])
    axs[j].set_yticks([0,50,100,150,200,250])
    axs[j].set_yticklabels([0,200,400,600,800,1000])
    axs[j].xaxis.set_label_position('top')
    images.append(axs[j].imshow(layers_true[j]))
    axs[j].label_outer()

# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.28, 0.765, 0.04])#位置[左,y,右,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='x-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\三层向斜背斜地层真实模型.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()

# %%
layer_pred_1 = np.zeros((256,256))
num = 8
for i in range(256):
    layer_pred_1[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_1[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_1[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_1[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_2 = np.zeros((256,256))
num = 16    
for i in range(256):
    layer_pred_2[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_2[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_2[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_2[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_3 = np.zeros((256,256))
num = 32
for i in range(256):
    layer_pred_3[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_3[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_3[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_3[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_4 = np.zeros((256,256))
num = 64
for i in range(256):
    layer_pred_4[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_4[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_4[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_4[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

# %%
layers_pred = [layer_pred_1,layer_pred_2,layer_pred_3,layer_pred_4]

# %%
Nr = 1
Nc = 4

fig, axs = plt.subplots(Nr, Nc,figsize=(12, 8))
fig.suptitle('三层向斜背斜地层预测模型',y=0.75,fontsize='xx-large')

images = []
# for i in range(Nr):
for j in range(Nc):
    # Generate data with a range that varies from one plot to the next.
    axs[j].set_title('预测')
    axs[j].xaxis.set_ticks_position('top')
    axs[j].set_xlabel('距离（m）')
    axs[j].set_ylabel('深度（m）')
    axs[j].set_xticks([0,100,200])
    axs[j].set_xticklabels([0,400,800])
    axs[j].set_yticks([0,50,100,150,200,250])
    axs[j].set_yticklabels([0,200,400,600,800,1000])
    axs[j].xaxis.set_label_position('top')
    images.append(axs[j].imshow(layers_pred[j]))
    axs[j].label_outer()

# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.28, 0.765, 0.04])#位置[左,y,右,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='x-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\三层向斜背斜地层预测模型.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()

# %%
layers =np.array([[layer_true_1,layer_true_2,layer_true_3,layer_true_4] ,[layer_pred_1,layer_pred_2,layer_pred_3,layer_pred_4]])

# %%
Nr = 2
Nc = 4

fig, axs = plt.subplots(Nr, Nc,figsize=(16, 10))
fig.suptitle('三层向斜背斜地层模型真实与预测对比',y=0.93,fontsize='xx-large')

images = []
for i in range(Nr):
    for j in range(Nc):
        # Generate data with a range that varies from one plot to the next.
        if i==0:
            axs[i,j].set_title('实际地层'+str(j+1))
        if i==1:
            axs[i,j].set_title('预测地层'+str(j+1))
        axs[i,j].xaxis.set_ticks_position('top')
        axs[i,j].set_xlabel('距离（m）')
        axs[i,j].set_ylabel('深度（m）')
        axs[i,j].set_xticks([0,100,200])
        axs[i,j].set_xticklabels([0,400,800])
        axs[i,j].set_yticks([0,50,100,150,200,250])
        axs[i,j].set_yticklabels([0,200,400,600,800,1000])
        axs[i,j].xaxis.set_label_position('top')
        images.append(axs[i,j].imshow(layers[i,j]))
#         axs[i,j].label_outer()

# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.05, 0.765, 0.04])#位置[x,y,宽,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='x-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.3, hspace=0.001)
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\三层向斜背斜地层模型真实与预测对比.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()

# %%
layer_true_1 = np.zeros((256,256))
num = 8
for i in range(256):
    layer_true_1[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_1[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_1[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_1[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_2 = np.zeros((256,256))
num = 16    
for i in range(256):
    layer_true_2[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_2[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_2[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_2[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_3 = np.zeros((256,256))
num = 32
for i in range(256):
    layer_true_3[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_3[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_3[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_3[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_4 = np.zeros((256,256))
num = 64
for i in range(256):
    layer_true_4[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_4[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_4[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_4[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]
    
layer_pred_1 = np.zeros((256,256))
num = 8
for i in range(256):
    layer_pred_1[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_1[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_1[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_1[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_2 = np.zeros((256,256))
num = 16    
for i in range(256):
    layer_pred_2[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_2[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_2[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_2[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_3 = np.zeros((256,256))
num = 32
for i in range(256):
    layer_pred_3[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_3[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_3[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_3[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_4 = np.zeros((256,256))
num = 64
for i in range(256):
    layer_pred_4[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_4[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_4[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_4[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]
    
layer_true_5 = np.zeros((256,256))
num = 12
for i in range(256):
    layer_true_5[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_5[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_5[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_5[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_6 = np.zeros((256,256))
num = 34    
for i in range(256):
    layer_true_6[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_6[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_6[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_6[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_7 = np.zeros((256,256))
num = 128
for i in range(256):
    layer_true_7[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_7[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_7[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_7[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]

layer_true_8 = np.zeros((256,256))
num = 200
for i in range(256):
    layer_true_8[0:int(y_depth_512_1_test[num,0,i]),i] = speed_list[int(y_class_512_1_test[num,0])]
    layer_true_8[int(y_depth_512_1_test[num,0,i]):int(y_depth_512_1_test[num,1,i]),i] = speed_list[int(y_class_512_1_test[num,1])]
    layer_true_8[int(y_depth_512_1_test[num,1,i]):int(y_depth_512_1_test[num,2,i]),i] = speed_list[int(y_class_512_1_test[num,2])]
    layer_true_8[int(y_depth_512_1_test[num,2,i]):,i] = speed_list[int(y_class_512_1_test[num,3])]
    
layer_pred_5 = np.zeros((256,256))
num = 12
for i in range(256):
    layer_pred_5[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_5[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_5[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_5[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_6 = np.zeros((256,256))
num = 34    
for i in range(256):
    layer_pred_6[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_6[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_6[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_6[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_7 = np.zeros((256,256))
num = 128
for i in range(256):
    layer_pred_7[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_7[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_7[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_7[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

layer_pred_8 = np.zeros((256,256))
num = 200
for i in range(256):
    layer_pred_8[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer_pred_8[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer_pred_8[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer_pred_8[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

# %%
layers =np.array([
    [layer_true_1,layer_true_2,layer_true_3,layer_true_4],
    [layer_pred_1,layer_pred_2,layer_pred_3,layer_pred_4],
    [layer_true_5,layer_true_6,layer_true_7,layer_true_8],
    [layer_pred_5,layer_pred_6,layer_pred_7,layer_pred_8]
    ])

# %%
Nr = 4
Nc = 4

fig, axs = plt.subplots(Nr, Nc,figsize=(16, 16))
fig.suptitle('三层向斜背斜地层模型真实与预测对比',y=0.95,fontsize='xx-large')

images = []
for i in range(Nr):
    for j in range(Nc):
        # Generate data with a range that varies from one plot to the next.
        if i==0 or i==2:
            axs[i,j].set_title('实际地层'+str((i//2)*4+j+1))
        if i==1 or i==3:
            axs[i,j].set_title('预测地层'+str((i//2)*4+j+1))
        axs[i,j].xaxis.set_ticks_position('top')
        axs[i,j].set_xlabel('距离（m）')
        axs[i,j].set_ylabel('深度（m）')
        axs[i,j].set_xticks([0,100,200])
        axs[i,j].set_xticklabels([0,400,800])
        axs[i,j].set_yticks([0,50,100,150,200,250])
        axs[i,j].set_yticklabels([0,200,400,600,800,1000])
        axs[i,j].xaxis.set_label_position('top')
        images.append(axs[i,j].imshow(layers[i,j]))
#         axs[i,j].label_outer()

# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.05, 0.765, 0.04])#位置[x,y,宽,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='x-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.3, hspace=0.4)
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\三层向斜背斜地层模型真实与预测对比.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()

# %%
y_test_depth_pred_1 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_depth_pred_1.npy')/4
y_test_speed_pred_1 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_speed_pred_1.npy')
y_test_speed_pred_logit_1 = np.load(r'E:\tools\写论文\图表数据\三层向斜背斜预测\data\y_test_speed_pred_logit_1.npy')
layer = np.zeros((256,256))
num = 123    
for i in range(256):
    layer[0:int(y_test_depth_pred_1[num,0,i]),i] = speed_list[int(y_test_speed_pred_1[num,0])]
    layer[int(y_test_depth_pred_1[num,0,i]):int(y_test_depth_pred_1[num,1,i]),i] = speed_list[int(y_test_speed_pred_1[num,1])]
    layer[int(y_test_depth_pred_1[num,1,i]):int(y_test_depth_pred_1[num,2,i]),i] = speed_list[int(y_test_speed_pred_1[num,2])]
    layer[int(y_test_depth_pred_1[num,2,i]):,i] = speed_list[int(y_test_speed_pred_1[num,3])]

# %%
# plt.title('还原后地层',y=1.16)
plt.xlabel("距离（m）")
plt.ylabel('深度（m）')
plt.xticks([0,50,100,150,200,250],[0,200,400,600,800,1000])
plt.yticks([0,50,100,150,200,250],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(layer)
cax = plt.axes([0.265,0.03,0.5,0.05])
cbar = plt.colorbar(cax=cax,orientation='horizontal')
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\地层生成图片_模型说明.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)

# %%
y_test_speed_pred_1[123]
# Out:
# array([2, 3, 4, 7], dtype=int64)

# %%
y_test_speed_pred_logit_1[123]
# Out:
# array([[1.1278516e-08, 5.8304238e-07, 9.9999928e-01, 8.5621657e-08,
#         4.9194178e-08, 9.4979469e-10, 9.0880176e-10, 9.3936336e-10],
#        [2.6336638e-10, 2.8664692e-07, 5.9890752e-08, 9.9999928e-01,
#         1.4170794e-07, 2.3974974e-07, 2.6116789e-10, 2.6005242e-10],
#        [7.9842583e-10, 7.8861834e-10, 8.2080085e-08, 1.3515023e-07,
#         9.9987841e-01, 2.4611653e-08, 1.2138514e-04, 7.8166529e-10],
#        [6.5950161e-09, 6.5042607e-09, 6.6325332e-09, 1.0175553e-08,
#         6.6082912e-08, 8.0561602e-09, 4.2929174e-03, 9.9570698e-01]],
#       dtype=float32)

# %%
y_test_depth_pred_1[123].shape
# Out:
# (3, 256)

# %%
plt.title("深度预测",y=1)
plt.ylabel("分界面在地下的深度（m）")
plt.xlabel("水平位置（m）")
# ax = plt.gca()
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
# ax.spines['left'].set_position(('data', 0))
# ax.spines['bottom'].set_position(('data', 0))
# ax.xaxis.set_label_position('top')
# ax.yaxis.set_label_position('right')
plt.xlim(0, 256)
plt.ylim(0, 256)
plt.xticks([0,50,100,150,200,250],[0,200,400,600,800,1000])
plt.yticks([0,50,100,150,200,250],[0,200,400,600,800,1000])
x = [i for i in range(256)]
plt.plot(x,y_test_depth_pred_1[123][0],label="第一层深度")
plt.plot(x,y_test_depth_pred_1[123][1],label="第二层深度")
plt.plot(x,y_test_depth_pred_1[123][2],label="第三层深度")
plt.legend()
plt.savefig(r'E:\tools\写论文\图表数据\三层向斜背斜预测\深度预测_模型说明.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
