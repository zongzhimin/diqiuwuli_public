# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from experiment1.model_em1 import FCZipSeismicDataV4
import numpy as np
import matplotlib.pyplot as plt

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
import json

# %%
data_json_f = open(r'E:\tools\写论文\图表数据\basic\dropout_过拟合\run-loss_all_2-tag-dev_loss.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_dev = np.array(data_json)
loss_dev_index = loss_dev[:,1]
loss_dev_loss = loss_dev[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\basic\dropout_过拟合\run-loss_all_2-tag-train_loss.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train = np.array(data_json)
loss_train_index = loss_train[:,1]
loss_train_loss = loss_train[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\basic\dropout_过拟合\run-loss_all_dropout-tag-dev_loss.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_dev_dropout = np.array(data_json)
loss_dev_dropout_index = loss_dev_dropout[:,1]
loss_dev_dropout_loss = loss_dev_dropout[:,2]

data_json_f = open(r'E:\tools\写论文\图表数据\basic\dropout_过拟合\run-loss_all_dropout-tag-train_loss.json','r')
data_json = json.load(data_json_f)
data_json_f.close()
loss_train_dropout = np.array(data_json)
loss_train_dropout_index = loss_train_dropout[:,1]
loss_train_dropout_loss = loss_train_dropout[:,2]

# %%
loss_train_dropout_index.shape
# Out:
# (1000,)

# %%
start1=150
start2=20
end1 = 500
end2 = 80
plt.title("dropout对训练的影响")
plt.ylabel("loss")
plt.xlabel("迭代次数")
plt.plot(loss_dev_index[start1:end1],loss_dev_loss[start1:end1],label='dev_loss')
plt.plot(loss_train_index[start1:end1],loss_train_loss[start1:end1],label='train_loss')
plt.plot(loss_dev_dropout_index[start2:end2],loss_dev_dropout_loss[start2:end2],label='dev_loss_dropout')
plt.plot(loss_train_dropout_index[start2:end2],loss_train_dropout_loss[start2:end2],label='train_loss_dropout')
plt.legend()
plt.savefig(r'E:\tools\写论文\图表数据\basic\dropout的影响.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)
