# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import colors

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
vpdata1 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\1\m_'+str(np.random.randint(0, 10))+'.vp',dtype=np.float32)
vpdata1 = vpdata1.reshape((512,512))
vpdata2 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\1\m_'+str(np.random.randint(0, 10))+'.vp',dtype=np.float32)
vpdata2 = vpdata2.reshape((512,512))
vpdata3 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\1\m_'+str(np.random.randint(0, 10))+'.vp',dtype=np.float32)
vpdata3 = vpdata3.reshape((512,512))

# %%
plt.figure(figsize=(18,12))
plt.subplot(1, 3, 1)
plt.suptitle('异常体模型1',y=0.75,fontsize='xx-large')
plt.title("数据1")
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
plt.xticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
plt.yticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(vpdata1.T)
plt.subplot(1, 3, 2)
plt.title("数据2")
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
plt.xticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
plt.yticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(vpdata2.T)
plt.subplot(1, 3, 3)
plt.title("数据3")
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
plt.xticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
plt.yticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(vpdata3.T)
plt.savefig(r'E:\tools\写论文\图表数据\异常体模型1图片.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)

# %%
marmousi_vp = np.load(r'E:\dataaaaaaaaaa\marmousi.vp.npy')

# %%
plt.figure(figsize=(18,12))
plt.title('marmousi模型',y=1.15,fontsize='xx-large')
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(marmousi_vp.T)
cax = plt.axes([0.125,0.3,0.775,0.05])
cbar = plt.colorbar(cax=cax,orientation='horizontal')
cbar.set_label('速度（m/s）',fontsize='xx-large')
plt.savefig(r'E:\tools\写论文\图表数据\marmousi模型.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)

# %%
import os

# %%
filePath = r'E:\tools\写论文\datas\data\yicangti\3'
name = os.listdir(filePath)

# %%
len(name)/3
# Out:
# 152.0

# %%
vps = []
for model in name:
    if model.endswith('vp'):
        vps.append(model)

# %%
len(vps)
# Out:
# 152

# %%
import random

# %%
random.shuffle(vps)
vpdata1 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\3\\'+vps[0],dtype=np.float32)
vpdata1 = vpdata1.reshape((512,512))
vpdata2 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\3\\'+vps[1],dtype=np.float32)
vpdata2 = vpdata2.reshape((512,512))
vpdata3 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\3\\'+vps[2],dtype=np.float32)
vpdata3 = vpdata3.reshape((512,512))

# %%
plt.figure(figsize=(18,12))
plt.subplot(1, 3, 1)
plt.suptitle('异常体模型2',y=0.75,fontsize='xx-large')
plt.title("数据1")
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
plt.xticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
plt.yticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(vpdata1.T)
plt.subplot(1, 3, 2)
plt.title("数据2")
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
plt.xticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
plt.yticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(vpdata2.T)
plt.subplot(1, 3, 3)
plt.title("数据3")
plt.ylabel("深度（m）")
plt.xlabel("距离（m）")
plt.xticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
plt.yticks([0,100,200,300,400,500],[0,200,400,600,800,1000])
ax = plt.gca()
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')
plt.imshow(vpdata3.T)
plt.savefig(r'E:\tools\写论文\图表数据\异常体模型2图片.jpg',bbox_inches='tight',dpi=300,pad_inches=0.5)

# %%
vpdatas = [vpdata1.T,vpdata2.T,vpdata3.T]
Nr = 1
Nc = 3

fig, axs = plt.subplots(Nr, Nc,figsize=(12, 8))
fig.suptitle('复杂地层下异常体模型',y=0.8,fontsize='xx-large')

images = []
# for i in range(Nr):
for j in range(Nc):
    # Generate data with a range that varies from one plot to the next.
    images.append(axs[j].imshow(vpdatas[j]))
    axs[j].label_outer()
    axs[j].xaxis.set_ticks_position('top')
    axs[j].set_xlabel('距离（m）')
    axs[j].set_ylabel('深度（m）')
    axs[j].set_xticks([0,100,200,300,400,500])
    axs[j].set_xticklabels([0,200,400,600,800,1000])
    axs[j].set_yticks([0,100,200,300,400,500])
    axs[j].set_yticklabels([0,200,400,600,800,1000])
    axs[j].xaxis.set_label_position('top')
# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.25, 0.765, 0.04])#位置[左,y,右,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='xx-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig(r'E:\tools\写论文\图表数据\异常体复杂模型2图片.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()

# %%
vpdata1 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\2\m_'+str(np.random.randint(0, 10))+'.vp',dtype=np.float32)
vpdata1 = vpdata1.reshape((512,512))
vpdata2 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\2\m_'+str(np.random.randint(0, 10))+'.vp',dtype=np.float32)
vpdata2 = vpdata2.reshape((512,512))
vpdata3 = np.fromfile(r'E:\tools\写论文\datas\data\yicangti\2\m_'+str(np.random.randint(0, 10))+'.vp',dtype=np.float32)
vpdata3 = vpdata3.reshape((512,512))

# %%
vpdatas = [vpdata1.T,vpdata2.T,vpdata3.T]
Nr = 1
Nc = 3

fig, axs = plt.subplots(Nr, Nc,figsize=(12, 8))
fig.suptitle('异常体不同速度模型',y=0.8,fontsize='xx-large')

images = []
# for i in range(Nr):
for j in range(Nc):
    # Generate data with a range that varies from one plot to the next.
    axs[j].label_outer()
    axs[j].xaxis.set_ticks_position('top')
    axs[j].set_xlabel('距离（m）')
    axs[j].set_ylabel('深度（m）')
    axs[j].set_xticks([0,100,200,300,400,500])
    axs[j].set_xticklabels([0,200,400,600,800,1000])
    axs[j].set_yticks([0,100,200,300,400,500])
    axs[j].set_yticklabels([0,200,400,600,800,1000])
    axs[j].xaxis.set_label_position('top')
    images.append(axs[j].imshow(vpdatas[j]))
    axs[j].label_outer()

# Find the min and max of all colors for use in setting the color scale.
vmin = min(image.get_array().min() for image in images)
vmax = max(image.get_array().max() for image in images)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
for im in images:
    im.set_norm(norm)
    
position=fig.add_axes([0.13, 0.25, 0.765, 0.04])#位置[左,y,右,高]
cbar  = fig.colorbar(images[0], ax=axs, cax=position, orientation='horizontal', fraction=.2)
cbar.set_label('速度（m/s）',fontsize='xx-large')

# Make images respond to changes in the norm of other images (e.g. via the
# "edit axis, curves and images parameters" GUI on Qt), but be careful not to
# recurse infinitely!
def update(changed_image):
    for im in images:
        if (changed_image.get_cmap() != im.get_cmap()
                or changed_image.get_clim() != im.get_clim()):
            im.set_cmap(changed_image.get_cmap())
            im.set_clim(changed_image.get_clim())


for im in images:
    im.callbacksSM.connect('changed', update)
plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig(r'E:\tools\写论文\图表数据\异常体速度模型3图片.jpg',bbox_inches='tight',dpi=300,pad_inches=0.2)
plt.show()
